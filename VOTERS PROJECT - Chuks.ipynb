# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
 voters = pd.read_csv("C:/Users/Owner/Documents/BAS=230/vrdb01_reduced.csv", low_memory=False)

# %%
voters.head()
# Out:
#   status_lbl street_type_lbl     city    zip race_lbl party_lbl gender_lbl  \
# 0          A              LN  RALEIGH  27607        U       DEM          U
# 1          A             AVE  RALEIGH  27607        W       UNA          F
# 2          A              ST  RALEIGH  27607        W       DEM          F
# 3          A              RD  RALEIGH  27605        B       DEM          M
# 4          A              ST  RALEIGH  27607        W       DEM          M
#
#    eoy_age precinct_lbl municipality_lbl    ...     05/06/2014 07/15/2014  \
# 0       27        01-01              RAL    ...            NaN        NaN
# 1       26        01-01              RAL    ...            NaN        NaN
# 2       61        01-01              RAL    ...            NaN        NaN
# 3       34        01-01              RAL    ...            NaN        NaN
# 4       62        01-01              RAL    ...            NaN        NaN
#
# ...

# %%
voters.shape
# Out:
# (137699, 29)

# %%
voters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137699 entries, 0 to 137698
# Data columns (total 29 columns):
# status_lbl          137699 non-null object
# street_type_lbl     133519 non-null object
# city                137699 non-null object
# zip                 137699 non-null int64
# race_lbl            137699 non-null object
# party_lbl           137699 non-null object
# gender_lbl          137699 non-null object
# eoy_age             137699 non-null int64
# precinct_lbl        137699 non-null object
# municipality_lbl    137699 non-null object
# ward_lbl            136969 non-null object
# 10/11/2011          24174 non-null object
# 11/08/2011          3503 non-null object
# 05/08/2012          39401 non-null object
# 07/17/2012          5146 non-null object
# 11/06/2012          74138 non-null object
# 03/12/2013          13 non-null object
# 10/08/2013          20209 non-null object
# 11/05/2013          100 non-null object
# 05/06/2014          18108 non-null object
# ...

# %%
voters.count()
# Out:
# status_lbl          137699
# street_type_lbl     133519
# city                137699
# zip                 137699
# race_lbl            137699
# party_lbl           137699
# gender_lbl          137699
# eoy_age             137699
# precinct_lbl        137699
# municipality_lbl    137699
# ward_lbl            136969
# 10/11/2011           24174
# 11/08/2011            3503
# 05/08/2012           39401
# 07/17/2012            5146
# 11/06/2012           74138
# 03/12/2013              13
# 10/08/2013           20209
# 11/05/2013             100
# 05/06/2014           18108
# 07/15/2014            1805
# 11/04/2014           54243
# 10/06/2015           18888
# 11/03/2015            3419
# 03/15/2016           48623
# 06/07/2016           14981
# 11/08/2016           92676
# 10/10/2017           27180
# 11/07/2017           27753
# dtype: int64

# %%
voters.isna()
# Out:
#         status_lbl  street_type_lbl   city    zip  race_lbl  party_lbl  \
# 0            False            False  False  False     False      False
# 1            False            False  False  False     False      False
# 2            False            False  False  False     False      False
# 3            False            False  False  False     False      False
# 4            False            False  False  False     False      False
# 5            False            False  False  False     False      False
# 6            False             True  False  False     False      False
# 7            False            False  False  False     False      False
# 8            False            False  False  False     False      False
# 9            False            False  False  False     False      False
# 10           False            False  False  False     False      False
# 11           False            False  False  False     False      False
# ...

# %%
voters.dtypes
# Out:
# status_lbl          object
# street_type_lbl     object
# city                object
# zip                  int64
# race_lbl            object
# party_lbl           object
# gender_lbl          object
# eoy_age              int64
# precinct_lbl        object
# municipality_lbl    object
# ward_lbl            object
# 10/11/2011          object
# 11/08/2011          object
# 05/08/2012          object
# 07/17/2012          object
# 11/06/2012          object
# 03/12/2013          object
# 10/08/2013          object
# 11/05/2013          object
# 05/06/2014          object
# 07/15/2014          object
# 11/04/2014          object
# 10/06/2015          object
# 11/03/2015          object
# 03/15/2016          object
# 06/07/2016          object
# 11/08/2016          object
# 10/10/2017          object
# 11/07/2017          object
# dtype: object

# %%
voters.isnull().sum()
# Out:
# status_lbl               0
# street_type_lbl       4180
# city                     0
# zip                      0
# race_lbl                 0
# party_lbl                0
# gender_lbl               0
# eoy_age                  0
# precinct_lbl             0
# municipality_lbl         0
# ward_lbl               730
# 10/11/2011          113525
# 11/08/2011          134196
# 05/08/2012           98298
# 07/17/2012          132553
# 11/06/2012           63561
# 03/12/2013          137686
# 10/08/2013          117490
# 11/05/2013          137599
# 05/06/2014          119591
# 07/15/2014          135894
# 11/04/2014           83456
# 10/06/2015          118811
# 11/03/2015          134280
# 03/15/2016           89076
# 06/07/2016          122718
# 11/08/2016           45023
# 10/10/2017          110519
# 11/07/2017          109946
# dtype: int64

# %%
#Change Column Names

# %%
voters.rename(columns={'10/11/2011':'Municipal_Board'}, inplace=True)

# %%
voters.rename(columns={'11/08/2011':'Municipal_Elect11'}, inplace=True)

# %%
voters.rename(columns={'05/08/2012':'Primary_Elect12'}, inplace=True)

# %%
voters.rename(columns={'07/17/2012':'Second_Primary_Elect12'}, inplace=True)

# %%
voters.rename(columns={'11/06/2012':'General_Elect12'}, inplace=True)

# %%
voters.rename(columns={'03/12/2013':'Garner_Bond_Ref'}, inplace=True)

# %%
voters.rename(columns={'10/08/2013':'Raleigh_Cary_Municipal13'}, inplace=True)

# %%
voters.rename(columns={'11/05/2013':'Municipal_Elect13'}, inplace=True)

# %%
voters.rename(columns={'05/06/2014':'Primary_Elect14'}, inplace=True)

# %%
voters.rename(columns={'07/15/2014':'Second_Primary_Elect14'}, inplace=True)

# %%
voters.rename(columns={'11/04/2014':'General_Elect14'}, inplace=True)

# %%
voters.rename(columns={'10/06/2015':'Raleighh_Cary_Municipal15'}, inplace=True)

# %%
voters.rename(columns={'11/03/2015':'Municipal_Elect15'}, inplace=True)

# %%
voters.rename(columns={'03/15/2016':'Primary_Elect16'}, inplace=True)

# %%
voters.rename(columns={'06/07/2016':'Primary_Elect16i'}, inplace=True)

# %%
voters.rename(columns={'11/08/2016':'General_Elect16'}, inplace=True)

# %%
voters.rename(columns={'10/10/2017':'Municipal_Elect17'}, inplace=True)

# %%
voters.rename(columns={'11/07/2017':'Municipal_Election_Runoff17'}, inplace=True)

# %%
#Replacing Categorical Class Values to Class Binary Values

# %%
voters.Municipal_Board  = voters.Municipal_Board.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.Municipal_Elect11  = voters.Municipal_Elect11.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.Primary_Elect12   = voters.Primary_Elect12.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.Second_Primary_Elect12   = voters.Second_Primary_Elect12  .str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.General_Elect12   = voters.General_Elect12.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.Garner_Bond_Ref     = voters.Garner_Bond_Ref.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.Raleigh_Cary_Municipal13     = voters.Raleigh_Cary_Municipal13.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.Municipal_Elect13    = voters.Municipal_Elect13.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.Primary_Elect14    = voters.Primary_Elect14.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.Second_Primary_Elect14    = voters.Second_Primary_Elect14 .str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.General_Elect14    = voters.General_Elect14.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.Raleighh_Cary_Municipal15     = voters.Raleighh_Cary_Municipal15.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.Municipal_Elect15    = voters.Municipal_Elect15.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.Primary_Elect16     = voters.Primary_Elect16.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1').str.replace('A', '6').str.replace('L', '7')

# %%
voters.Primary_Elect16i     = voters.Primary_Elect16i.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1')

# %%
voters.General_Elect16   = voters.General_Elect16.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1')

# %%
voters.Municipal_Elect17   = voters.Municipal_Elect17.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1')

# %%
voters.Municipal_Election_Runoff17   = voters.Municipal_Election_Runoff17.str.replace('V', '5').str.replace('M', '4').str.replace('O', '3').str.replace('P', '2').str.replace('T', '1')

# %%
voters.party_lbl  = voters.party_lbl.str.replace('DEM', '1').str.replace('UNA', '2').str.replace('REP', '3').str.replace('LIB', '4')

# %%
voters.status_lbl  = voters.status_lbl.str.replace('A', '1').str.replace('I', '0')

# %%
voters.gender_lbl  = voters.gender_lbl.str.replace('F', '2').str.replace('M', '1').str.replace('U', '0')

# %%
voters.race_lbl  = voters.race_lbl.str.replace('W', '1').str.replace('B', '2').str.replace('U', '3').str.replace('O', '4').str.replace('A', '5').str.replace('M', '6').str.replace('I', '7')

# %%
voters.street_type_lbl = voters.street_type_lbl.str.replace('DR', '1').str.replace('ST', '2').str.replace('RD', '3').str.replace('CT', '4').str.replace('AVE', '5').str.replace('LN', '6').str.replace('PL', '7').str.replace('CIR', '8').str.replace('WAY', '9').str.replace('BLVD', '10').str.replace('TRL', '11').str.replace('PKWY', '12').str.replace('HL', '13').str.replace('TER', '14').str.replace('PT', '15').str.replace('CV', '16').str.replace('RUN', '17').str.replace('XING', '18').str.replace('LNDG', '19').str.replace('SQ', '20').str.replace('ALY', '21').str.replace('CRES', '22').str.replace('CMNS', '23').str.replace('KNL', '24')

# %%
voters.city = voters.city.str.replace('RALEIGH', '1').str.replace('GARNER', '0')

# %%
voters.ward_lbl = voters.ward_lbl.str.replace('R-D', '1').str.replace('R-C', '2').str.replace('R-A', '3').str.replace('R-E', '4').str.replace('R-B', '5').str.replace('0', '0')

# %%
#Checking for Changes Done

# %%
voters.head()
# Out:
#   status_lbl street_type_lbl city    zip race_lbl party_lbl gender_lbl  \
# 0          1               6    1  27607        3         1          0
# 1          1               5    1  27607        1         2          2
# 2          1               2    1  27607        1         1          2
# 3          1               3    1  27605        2         1          1
# 4          1               2    1  27607        1         1          1
#
#    eoy_age precinct_lbl municipality_lbl             ...              \
# 0       27        01-01              RAL             ...
# 1       26        01-01              RAL             ...
# 2       61        01-01              RAL             ...
# 3       34        01-01              RAL             ...
# 4       62        01-01              RAL             ...
#
#   Primary_Elect14 Second_Primary_Elect14 General_Elect14  \
# 0             NaN                    NaN             NaN
# 1             NaN                    NaN             NaN
# ...

# %%
#Filling NaN in each Columns with Zero(0)

# %%
voters.fillna(0, inplace=True)

# %%
#Checking for Changes Done

# %%
voters.head()
# Out:
#   status_lbl street_type_lbl city    zip race_lbl party_lbl gender_lbl  \
# 0          1               6    1  27607        3         1          0
# 1          1               5    1  27607        1         2          2
# 2          1               2    1  27607        1         1          2
# 3          1               3    1  27605        2         1          1
# 4          1               2    1  27607        1         1          1
#
#    eoy_age precinct_lbl municipality_lbl             ...              \
# 0       27        01-01              RAL             ...
# 1       26        01-01              RAL             ...
# 2       61        01-01              RAL             ...
# 3       34        01-01              RAL             ...
# 4       62        01-01              RAL             ...
#
#   Primary_Elect14 Second_Primary_Elect14 General_Elect14  \
# 0               0                      0               0
# 1               0                      0               0
# ...

# %%
#Checking to make sure there isn't any Missing values

# %%
voters.isnull().sum()
# Out:
# status_lbl                     0
# street_type_lbl                0
# city                           0
# zip                            0
# race_lbl                       0
# party_lbl                      0
# gender_lbl                     0
# eoy_age                        0
# precinct_lbl                   0
# municipality_lbl               0
# ward_lbl                       0
# Municipal_Board                0
# Municipal_Elect11              0
# Primary_Elect12                0
# Second_Primary_Elect12         0
# General_Elect12                0
# Garner_Bond_Ref                0
# Raleigh_Cary_Municipal13       0
# Municipal_Elect13              0
# Primary_Elect14                0
# Second_Primary_Elect14         0
# General_Elect14                0
# Raleighh_Cary_Municipal15      0
# Municipal_Elect15              0
# Primary_Elect16                0
# Primary_Elect16i               0
# General_Elect16                0
# Municipal_Elect17              0
# ...

# %%
#Checking the dataset and each columns are equal with replacing values and filling missing values

# %%
voters.count()
# Out:
# status_lbl                     137699
# street_type_lbl                137699
# city                           137699
# zip                            137699
# race_lbl                       137699
# party_lbl                      137699
# gender_lbl                     137699
# eoy_age                        137699
# precinct_lbl                   137699
# municipality_lbl               137699
# ward_lbl                       137699
# Municipal_Board                137699
# Municipal_Elect11              137699
# Primary_Elect12                137699
# Second_Primary_Elect12         137699
# General_Elect12                137699
# Garner_Bond_Ref                137699
# Raleigh_Cary_Municipal13       137699
# Municipal_Elect13              137699
# Primary_Elect14                137699
# Second_Primary_Elect14         137699
# General_Elect14                137699
# Raleighh_Cary_Municipal15      137699
# Municipal_Elect15              137699
# Primary_Elect16                137699
# ...

# %%
#Check types of each column because it needs to be in a Binary form for modeling

# %%
voters.dtypes
# Out:
# status_lbl                     object
# street_type_lbl                object
# city                           object
# zip                             int64
# race_lbl                       object
# party_lbl                      object
# gender_lbl                     object
# eoy_age                         int64
# precinct_lbl                   object
# municipality_lbl               object
# ward_lbl                       object
# Municipal_Board                object
# Municipal_Elect11              object
# Primary_Elect12                object
# Second_Primary_Elect12         object
# General_Elect12                object
# Garner_Bond_Ref                object
# Raleigh_Cary_Municipal13       object
# Municipal_Elect13              object
# Primary_Elect14                object
# Second_Primary_Elect14         object
# General_Elect14                object
# Raleighh_Cary_Municipal15      object
# Municipal_Elect15              object
# Primary_Elect16                object
# ...

# %%
#Change Columns to Numeric

# %%
voters[["Municipal_Board", "Municipal_Elect11"]] = voters[["Municipal_Board", "Municipal_Elect11"]].apply(pd.to_numeric)

# %%
voters[["Primary_Elect12", "Second_Primary_Elect12"]] = voters[["Primary_Elect12", "Second_Primary_Elect12"]].apply(pd.to_numeric)

# %%
voters[["General_Elect12", "Garner_Bond_Ref"]] = voters[["General_Elect12", "Garner_Bond_Ref"]].apply(pd.to_numeric)

# %%
voters[["Raleigh_Cary_Municipal13", "Municipal_Elect13"]] = voters[["Raleigh_Cary_Municipal13", "Municipal_Elect13"]].apply(pd.to_numeric)

# %%
voters[["Primary_Elect14", "Second_Primary_Elect14"]] = voters[["Primary_Elect14", "Second_Primary_Elect14"]].apply(pd.to_numeric)

# %%
voters[["General_Elect14", "Raleighh_Cary_Municipal15"]] = voters[["General_Elect14", "Raleighh_Cary_Municipal15"]].apply(pd.to_numeric)

# %%
voters[["Municipal_Elect15", "Primary_Elect16"]] = voters[["Municipal_Elect15", "Primary_Elect16"]].apply(pd.to_numeric)

# %%
voters[["Primary_Elect16i", "General_Elect16"]] = voters[["Primary_Elect16i", "General_Elect16"]].apply(pd.to_numeric)

# %%
voters[["Municipal_Elect17", "Municipal_Election_Runoff17"]] = voters[["Municipal_Elect17", "Municipal_Election_Runoff17"]].apply(pd.to_numeric)

# %%
voters[["party_lbl", "status_lbl"]] = voters[["party_lbl", "status_lbl"]].apply(pd.to_numeric)

# %%
voters[["gender_lbl", "race_lbl"]] = voters[["gender_lbl", "race_lbl"]].apply(pd.to_numeric)

# %%
voters[["city"]] = voters[["city",]].apply(pd.to_numeric)

# %%
voters[["ward_lbl"]] = voters[["ward_lbl"]].apply(pd.to_numeric)

# %%
#Check Column types for changes

# %%
voters.dtypes
# Out:
# status_lbl                      int64
# street_type_lbl                object
# city                            int64
# zip                             int64
# race_lbl                        int64
# party_lbl                       int64
# gender_lbl                      int64
# eoy_age                         int64
# precinct_lbl                   object
# municipality_lbl               object
# ward_lbl                        int64
# Municipal_Board                 int64
# Municipal_Elect11               int64
# Primary_Elect12                 int64
# Second_Primary_Elect12          int64
# General_Elect12                 int64
# Garner_Bond_Ref                 int64
# Raleigh_Cary_Municipal13        int64
# Municipal_Elect13               int64
# Primary_Elect14                 int64
# Second_Primary_Elect14          int64
# General_Elect14                 int64
# Raleighh_Cary_Municipal15       int64
# Municipal_Elect15               int64
# Primary_Elect16                 int64
# ...

# %%
#Heatmap Correlation for each Columns

# %%
import seaborn as sns
plt.figure(figsize=(12,10))
cor = voters.corr()
sns.heatmap(cor, annot=True,cmap=plt.cm.Reds)
plt.show()

# %%
#Histogram

# %%
voters.hist(sharex=False, sharey=False, xlabelsize=1, ylabelsize=1)
plt.show()

# %%
#Supporting Correlation

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(voters.corr(), vmin=-1, vmax=1, interpolation='none')
fig.colorbar(cax)
plt.show()

# %%
#Check Relationship with X variables by Y variable

# %%
import seaborn as sns
# %matplotlib inline
sns.pairplot(voters, x_vars=['status_lbl', 'zip', 'eoy_age', 'Municipal_Board', 'Municipal_Elect11', 'race_lbl'],
             y_vars='party_lbl', size=7, aspect=0.7, kind='reg')
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Owner\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# %matplotlib inline
sns.pairplot(voters, x_vars=['gender_lbl','Primary_Elect12', 'Second_Primary_Elect12', 'General_Elect12', 'Garner_Bond_Ref', 'Raleigh_Cary_Municipal13'],
             y_vars='party_lbl', size=7, aspect=0.7, kind='reg')
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
# %matplotlib inline
sns.pairplot(voters, x_vars=['Municipal_Elect13', 'Primary_Elect14', 'Second_Primary_Elect14', 'General_Elect14', 'Raleighh_Cary_Municipal15', 'ward_lbl'],
             y_vars='party_lbl', size=7, aspect=0.7, kind='reg')
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
# %matplotlib inline
sns.pairplot(voters, x_vars=['Municipal_Elect15', 'Primary_Elect16', 'Primary_Elect16i', 'General_Elect16', 'Municipal_Elect17', 'Municipal_Election_Runoff17', 'city'],
             y_vars='party_lbl', size=7, aspect=0.7, kind='reg')
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Feature Collection for X variable

# %%
from sklearn import model_selection

feature_cols = ['status_lbl', 'zip', 'eoy_age', 'gender_lbl', 'race_lbl', 'city', 'ward_lbl', 'Municipal_Board', 'Municipal_Elect11', 'Primary_Elect12', 'Second_Primary_Elect12',
               'General_Elect12', 'Garner_Bond_Ref', 'Raleigh_Cary_Municipal13', 'Municipal_Elect13', 'Primary_Elect14','Second_Primary_Elect14',
               'General_Elect14', 'Raleighh_Cary_Municipal15', 'Municipal_Elect15', 'Primary_Elect16', 'Primary_Elect16i',
               'General_Elect16', 'Municipal_Elect17', 'Municipal_Election_Runoff17']
X = voters[feature_cols]

# %%
#Target variable

# %%
target = ['party_lbl']
y = voters[target]

# %%
#Train and Test Data

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   """
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
#KNN CLASSIFICATION

# %%
#KNN Classification
from sklearn.neighbors import KNeighborsClassifier
clf=KNeighborsClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
ypredict=knn.predict(X_test)
print(metrics.confusion_matrix(y_test, ypredict))
print("Accuracy Score =", metrics.accuracy_score(y_test, ypredict))
# Out:
# [[14092  4558   906     5]
#  [ 7727  5416  1030     7]
#  [ 3769  2258  1269     0]
#  [  125   124    24     0]]
# Accuracy Score = 0.5029532800774631

# %%
#LOGISTIC REGRESSION FOR CLASSIFICATION

# %%
# Logistic Regression Sample Code
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
ypredict=clf.predict(X_test)
print(metrics.confusion_matrix(y_test, ypredict))
print("Accuracy Score =", metrics.accuracy_score(y_test, ypredict))
# Out:
# [[14625  4931     5     0]
#  [ 7117  6990    73     0]
#  [ 4251  2685   360     0]
#  [  109   164     0     0]]
# Accuracy Score = 0.5319535221496006

# %%
#DECISION TREE FOR CLASSIFICATION

# %%
#Decision Tree
from sklearn import tree
clf = tree.DecisionTreeClassifier(criterion = 'entropy', min_samples_leaf = 20)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=20, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
ypredict=dtc.predict(X_test)
print(metrics.confusion_matrix(y_test, ypredict))
print("Accuracy Score =", metrics.accuracy_score(y_test, ypredict))
# Out:
# [[13109  5203  1249     0]
#  [ 6177  6860  1143     0]
#  [ 2565  2900  1831     0]
#  [   92   162    19     0]]
# Accuracy Score = 0.5277172597434036

# %%
#GaussuanNB(Naive_Bayes)

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(X_train, y_train)
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
ypredict=clf.predict(X_test)
print(metrics.confusion_matrix(y_test, ypredict))
print("Accuracy Score =", metrics.accuracy_score(y_test, ypredict))
# Out:
# [[  794     3  4892 13872]
#  [  290     9  2154 11727]
#  [   61     2  2327  4906]
#  [    3     0    17   253]]
# Accuracy Score = 0.08189300411522633

# %%
#BONUS

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
ypredict=clf.predict(X_test)
print(metrics.confusion_matrix(y_test, ypredict))
print("Accuracy Score =", metrics.accuracy_score(y_test, ypredict))
# Out:
# [[13872  4187  1471    31]
#  [ 5487  6828  1827    38]
#  [ 2167  2593  2520    16]
#  [   82   140    46     5]]
# Accuracy Score = 0.5622125393367223
